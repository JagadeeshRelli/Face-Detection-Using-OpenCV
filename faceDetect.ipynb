# %% [markdown]
# # Loading the necessary libraries

# %%
# Import the necessary libraries
import numpy as np
import cv2 
import matplotlib.pyplot as plt

# %% [markdown]
# ## defining a function to convert image from BGR to RGB

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ### Loading the classifier for frontal face

# %%
haar_cascade_face = cv2.CascadeClassifier('data/haarcascade_frontalface_alt2.xml')

# %% [markdown]
# ### function to detect faces

# %%
def detect_faces(cascade, test_image, scaleFactor = 1.1):
    # creating a dup copy
    image_copy = test_image.copy()
    
    #convert the test image to gray scale as opencv face detector expects gray images
    gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)
    
    # Applying the haar classifier to detect faces
    faces_rect = cascade.detectMultiScale(gray_image, scaleFactor=scaleFactor, minNeighbors=5)
    
    for (x, y, w, h) in faces_rect:
        cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)
        
    return image_copy

# %% [markdown]
# ### Testing the function on image

# %%
#loading image
test_image2 = cv2.imread('data/pic.jpg')

#calling the function to detect faces
faces = detect_faces(haar_cascade_face, test_image2)

#converting to RGB and display image
plt.imshow(convertToRGB(faces))

# %% [markdown]
# ### Testing the function on a group photograph

# %%
#loading image
test_image2 = cv2.imread('data/group2.jpg')

#calling the function to detect faces
faces = detect_faces(haar_cascade_face, test_image2)

#converting to RGB and display image
plt.imshow(convertToRGB(faces))

# %% [markdown]
# ### Saving the Image

# %%
 cv2.imwrite('image1.png',faces)
# Out:
# True
